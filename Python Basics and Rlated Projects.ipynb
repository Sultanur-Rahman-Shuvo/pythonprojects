# %%
x=y=z = "hello world!\n"
print(x,y,z)
# Out:
# hello world!
#  hello world!
#  hello world!

# %%
#camel case

testDriveHome = "hello team"

# %%
#pascal case

TestDriveHome = "hello girl"

# %%
#snake case

test_drive_home = "hello boy"

# %%
a = "hello world!"
print(a[:5])
# Out:
# hello

# %%
#list

[1,2,"vanilla javascript",True]
# Out:
# [1, 2, 'vanilla javascript', True]

# %%
ice_cream = ["chocolate","strawberry","vanilla"]
ice_cream.append("mango")
print(ice_cream)
# Out:
# ['chocolate', 'strawberry', 'vanilla', 'mango']

# %%
nest_list = ["vanilla",3,["spoon","spray"],True]
nest_list[2][1]
# Out:
# 'spray'

# %%
#tuple

tuple_scoops = (1,3,4,5)
tuple_scoops.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 #tuple
#       3 tuple_scoops = (1,3,4,5)
# ----> 4 tuple_scoops.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#sets
daily_prints_log = {1,2,3,5,54,9}
print(daily_prints_log)
# Out:
# {1, 2, 3, 5, 54, 9}

# %%
wifes_daily_prints_log = {1,2,6,4,6,}
print(wifes_daily_prints_log)
# Out:
# {1, 2, 4, 6}

# %%
print(daily_prints_log | wifes_daily_prints_log)
# Out:
# {1, 2, 3, 4, 5, 6, 9, 54}

# %%
print(daily_prints_log & wifes_daily_prints_log)
# Out:
# {1, 2}

# %%
print(wifes_daily_prints_log - daily_prints_log)
# Out:
# {4, 6}

# %%
print(wifes_daily_prints_log ^ daily_prints_log)
# Out:
# {3, 4, 5, 54, 6, 9}

# %%
#dictionaries
#key/value pair

dict_cream = {'name': 'shuvo', 'weekly intake': 5, 'favourite ice cream': ['MCC','chocolate']}
print(dict_cream)
# Out:
# {'name': 'shuvo', 'weekly intake': 5, 'favourite ice cream': ['MCC', 'chocolate']}

# %%
dict_cream.values()
# Out:
# dict_values(['shuvo', 5, ['MCC', 'chocolate']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favourite ice cream'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'shuvo'), ('weekly intake', 5), ('favourite ice cream', ['MCC', 'chocolate'])])

# %%
dict_cream['name']
# Out:
# 'shuvo'

# %%
dict_cream['name'] = "sultan"
print(dict_cream['name'])
# Out:
# sultan

# %%
print(dict_cream)
# Out:
# {'name': 'sultan', 'weekly intake': 5, 'favourite ice cream': ['MCC', 'chocolate']}

# %%
dict_cream.update({'name': 'shuvo', 'weekly intake': 5, 'favourite ice cream': "mango flavour"})
print(dict_cream)
# Out:
# {'name': 'shuvo', 'weekly intake': 5, 'favourite ice cream': 'mango flavour'}

# %%
del dict_cream['name']
print(dict_cream)
# Out:
# {'weekly intake': 5, 'favourite ice cream': 'mango flavour'}

# %%
#membership operators


ice_cream = "i love chocolate falvoured ice cream"
"love" in ice_cream
# Out:
# True

# %%
scoops = [1,3,4,45,7]
7 not in scoops
# Out:
# False

# %%
#if else condition

if 25>10:
    print("it worked!")
# Out:
# it worked!

# %%
integers = [1,2,3,4,5]
for numbers in integers:
    print(numbers)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
integers = [1,2,3,4,5]
for numbers in integers:
    print("yep")
# Out:
# yep
# yep
# yep
# yep
# yep

# %%
ice_cream_dict = {"name": "shuvo", "age": 22, "gender": "male"}
for key,value in ice_cream_dict.items():
    print(key,"=",value)
# Out:
# name = shuvo
# age = 22
# gender = male

# %%
person = ["shuvo", "srabony"]
married_to = ["unknown", "rafid"]

for one in person:
    for two in married_to:
        print(one," knows ",two)
# Out:
# shuvo  knows  unknown
# shuvo  knows  rafid
# srabony  knows  unknown
# srabony  knows  rafid

# %%
number = 0
while number<5:
    print(number)
    if number == 3:
        break
    number = number+1
# Out:
# 0
# 1
# 2
# 3

# %%
#functions

def func():
    print("we did it!")
    
func()
# Out:
# we did it!

# %%
def number_squared(num):
    print(num**2)
number_squared(5)
# Out:
# 25

# %%
def number_squared_cust(num,power):
    print(num**power)

# %%
number_squared_cust(5,3)
# Out:
# 125

# %%
#arbitrary argument

args_tuple = (5,6,7,76,100)

def number_args(*number):
    print(number[0]*number[1])
    
number_args(*args_tuple)
# Out:
# 30

# %%
#keyword argument

def number_squared_cust(num,power):
    print(num**power)
number_squared_cust(power = 5,num = 3)
# Out:
# 243

# %%
#arbitrary keyword argument

def number_shuvo(**num):
    print("My number is " + num["integer"] + " and my other number is " + num["integer2"])
number_shuvo(integer = "01741461466" , integer2 = "017209594056")
# Out:
# My number is 01741461466 and my other number is 017209594056

# %%
#convert data types

list_hello = [1,34,5,34,5,7]
set(list_hello)
# Out:
# {1, 5, 7, 34}

# %%
list_str = "hello world!"
set(list_str)
# Out:
# {' ', '!', 'd', 'e', 'h', 'l', 'o', 'r', 'w'}

# %%
list_str = "hello world!"
list(list_str)
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!']

# %%
dict_men = {"name": "shuvo", "age": "22"}
list(dict_men.items())
# Out:
# [('name', 'shuvo'), ('age', '22')]

# %%
#creating BMI calculator

# %%
#BMI = (weight in pounds x 703) / (height in inches x height in inches)

# %%
name = input("Enter your name: ")

weight = int(input("Enter your weight in pounds: "))
height = int(input("Enter your weight in pounds: "))
BMI = (weight * 703) / (height * height)
print(BMI)

if BMI>0:
    if BMI<18.5:
        print(name +", you are underwight.")
    elif BMI<=24.9:  
        print(name +", you are normal weight.")
    elif (BMI<29.9):
        print(name +", you are overweight.")
    elif (BMI<34.9):
        print(name +", you are obese.")
    elif (BMI<39.9):
        print(name +", you are severely obese.")
    else:
        print(name +", you are morbidly obese.")
else:
    print("Enter valid input")
# Out:
# Enter your name: shuvo
# Enter your weight in pounds: 170
# Enter your weight in pounds: 69
# 25.101869355177485
# shuvo, you are overweight.

# %%
#Automatic file sorter in file explorer


import os,shutil

path = r"C:/Users/sulta/Downloads/Python File Project/"

file_name = os.listdir(path)

folder_names = ["csv files","image files","text files"]

for loop in range(0,2):
    if not os.path.exists(path + folder_names[loop]):
        print(path + folder_names[loop])
        os.makedirs(path + folder_names[loop])
        
        
for file in file_name:
    if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".jpg" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)
    elif ".txt" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)

# %%
#BeautifulSoup and Requests


from bs4 import BeautifulSoup
import requests

url = "https://www.scrapethissite.com/pages/forms/"
# Out:
# <Response [200]>

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, "html")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
#find and find next

from bs4 import BeautifulSoup
import requests

url = "https://www.scrapethissite.com/pages/forms/"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, "html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.find("div")
# Out:
# <div class="container">
# <div class="col-md-12">
# <ul class="nav nav-tabs">
# <li id="nav-homepage">
# <a class="nav-link hidden-sm hidden-xs" href="/">
# <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                 Scrape This Site
#                             </a>
# </li>
# <li id="nav-sandbox">
# <a class="nav-link" href="/pages/">
# <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                 Sandbox
#                             </a>
# </li>
# <li id="nav-lessons">
# <a class="nav-link" href="/lessons/">
# <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                 Lessons
#                             </a>
# </li>
# <li id="nav-faq">
# <a class="nav-link" href="/faq/">
# <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                 FAQ
#                             </a>
# </li>
# <li class="pull-right" id="nav-login">
# ...

# %%
soup.find_all("p",class_ = "lead")
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>]

# %%
soup.find("p",class_ = "lead").text.strip()
# Out:
# 'Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.'

# %%
soup.find_all("th")
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
soup.find("th").text.strip()
# Out:
# 'Team Name'

# %%
#scraping data from real website


from bs4 import BeautifulSoup
import requests

url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue"

page = requests.get(url)

soup = BeautifulSoup(page.text,"html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies in the United States by revenue - Wikipedia</title>
# ...

# %%
soup.find("table")
# Out:
# <table class="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove" role="presentation"><tbody><tr><td class="mbox-image"><div class="mbox-image-div"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Question_book-new.svg"><img alt="" class="mw-file-element" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></span></div></td><td class="mbox-text"><div class="mbox-text-span">This article <b>needs additional citations for <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a></b>.<span class="hide-when-compact"> Please help <a class="external t
# ...

# %%
soup.find_all("table")[1]
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
soup.find("table",class_ = "wikitable sortable")
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
table = soup.find_all("table")[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
world_titles = table.find_all("th")

# %%
print(world_titles)
# Out:
# [<th>Rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Revenue <br/>(USD millions)
# </th>, <th>Revenue growth
# </th>, <th>Employees
# </th>, <th>Headquarters
# </th>, <th>Rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Revenue <br/>(USD billions)
# </th>, <th>Employees
# </th>, <th>Headquarters
# </th>, <th>Rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Profits<br/>(USD millions)
# </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]

# %%
print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth', 'Employees', 'Headquarters']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all("tr")

# %%
for row in column_data[1:]:
    row_data = row.find_all("td")
    individual_row_data = [data.text.strip() for data in row_data]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank                      Name                    Industry  \
# 0     1                   Walmart                      Retail
# 1     2                    Amazon  Retail and Cloud Computing
# 2     3               Exxon Mobil          Petroleum industry
# 3     4                     Apple        Electronics industry
# 4     5        UnitedHealth Group                  Healthcare
# ..  ...                       ...                         ...
# 95   96                  Best Buy                      Retail
# 96   97      Bristol-Myers Squibb     Pharmaceutical industry
# 97   98           United Airlines                     Airline
# 98   99  Thermo Fisher Scientific      Laboratory instruments
# 99  100                  Qualcomm        Airspace and defense
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df.to_csv(r"Downloads\Companies.csv", index = False)

# %%
#Reading in Files

import pandas as pd
df = pd.read_csv(r"C:\Users\sulta\Downloads\Read Files\countries of the world.csv")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_csv(r"C:\Users\sulta\Downloads\Read Files\countries of the world.txt", sep = "\t")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_table(r"C:\Users\sulta\Downloads\Read Files\countries of the world.txt")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_table(r"C:\Users\sulta\Downloads\Read Files\countries of the world.csv", sep = ",")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_json(r"C:\Users\sulta\Downloads\Read Files\json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df = pd.read_excel(r"C:\Users\sulta\Downloads\Read Files\world_population_excel_workbook.xlsx", sheet_name = "Sheet1")
df
# Out:
#      Rank CCA3                           Country              Capital
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda       Saint Johnâ€™s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
pd.set_option("display.max.rows",235)

# %%
pd.set_option("display.max.columns",40)

# %%
df2 = pd.read_excel(r"C:\Users\sulta\Downloads\Read Files\world_population_excel_workbook.xlsx", sheet_name = "Sheet1")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    object
#  2   Country  234 non-null    object
#  3   Capital  234 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.4+ KB

# %%
df2.shape
# Out:
# (234, 4)

# %%
df2.head(10)
# Out:
#    Rank CCA3              Country           Capital
# 0    36  AFG          Afghanistan             Kabul
# 1   138  ALB              Albania            Tirana
# 2    34  DZA              Algeria           Algiers
# 3   213  ASM       American Samoa         Pago Pago
# 4   203  AND              Andorra  Andorra la Vella
# 5    42  AGO               Angola            Luanda
# 6   224  AIA             Anguilla        The Valley
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s
# 8    33  ARG            Argentina      Buenos Aires
# 9   140  ARM              Armenia           Yerevan

# %%
df2.tail(10)
# Out:
#      Rank CCA3            Country       Capital
# 224    43  UZB         Uzbekistan      Tashkent
# 225   181  VUT            Vanuatu     Port-Vila
# 226   234  VAT       Vatican City  Vatican City
# 227    51  VEN          Venezuela       Caracas
# 228    16  VNM            Vietnam         Hanoi
# 229   226  WLF  Wallis and Futuna      Mata-Utu
# 230   172  ESH     Western Sahara     El AaiÃºn
# 231    46  YEM              Yemen         Sanaa
# 232    63  ZMB             Zambia        Lusaka
# 233    74  ZWE           Zimbabwe        Harare

# %%
df2["Rank"]
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
# 5       42
# 6      224
# 7      201
# 8       33
# 9      140
# 10     198
# 11      55
# 12      99
# 13      91
# 14     176
# 15     154
# 16       8
# 17     186
# 18      96
# 19      81
# 20     177
# 21      77
# 22     206
# 23     165
# 24      80
# 25     137
# 26     144
# 27       7
# 28     221
# 29     175
# 30     108
# 31      58
# 32      78
# 33      73
# 34      53
# 35      39
# 36     171
# 37     205
# 38     117
# 39      69
# 40      65
# 41       1
# 42      28
# 43     163
# 44     223
# 45     124
# 46     130
# 47      85
# 48     189
# 49     158
# 50      88
# 51     115
# 52     160
# 53     204
# 54      84
# 55      15
# 56      67
# 57      14
# 58     112
# 59     152
# 60     132
# 61     156
# 62     159
# 63      12
# 64     231
# 65     209
# 66     162
# 67     118
# 68      23
# 69     184
# 70     183
# 71     146
# 72     142
# 73     131
# 74      19
# 75      47
# ...

# %%
df2.loc[224]
# Out:
# Rank               43
# CCA3              UZB
# Country    Uzbekistan
# Capital      Tashkent
# Name: 224, dtype: object

# %%
df2.loc['Uzbekistan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df2.loc['Uzbekistan']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
df2.iloc[224]
# Out:
# Rank               43
# CCA3              UZB
# Country    Uzbekistan
# Capital      Tashkent
# Name: 224, dtype: object

# %%
#filtering and ordering


import pandas as pd

df = pd.read_csv(r"C:\Users\sulta\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df[df["Rank"]<=10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# ...

# %%
specific_countries = ["Bangladesh","Brazil"]
df[df["Country"].isin(specific_countries)]
# Out:
#     Rank CCA3     Country   Capital      Continent  2022 Population  \
# 16     8  BGD  Bangladesh     Dhaka           Asia      171186372.0
# 27     7  BRA      Brazil  Brasilia  South America      215313498.0
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 16      167420951.0      157830000.0      148391139.0      129193327.0
# 27      213196304.0      205188205.0      196353492.0      175873720.0
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 16      107147651.0       83929765.0       67541860.0    147570.0
# 27      150706446.0      122288383.0       96369875.0   8515767.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 16          1160.0350       1.0108                         2.15
# 27            25.2841       1.0046                         2.70

# %%
df[df["Country"].str.contains("United")]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df2 = df.set_index("Country")
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df2.filter(items = ["Continent","CCA3"], axis = 1)
# Out:
#                   Continent CCA3
# Country
# Afghanistan            Asia  AFG
# Albania              Europe  ALB
# Algeria              Africa  DZA
# American Samoa      Oceania  ASM
# Andorra              Europe  AND
# ...                     ...  ...
# Wallis and Futuna   Oceania  WLF
# Western Sahara       Africa  ESH
# Yemen                  Asia  YEM
# Zambia               Africa  ZMB
# Zimbabwe             Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ["Zimbabwe"], axis = 0)
# Out:
#           Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Country
# Zimbabwe    74  ZWE  Harare    Africa       16320537.0       15669666.0
#
#           2015 Population  2010 Population  2000 Population  1990 Population  \
# Country
# Zimbabwe       14154937.0       12839771.0       11834676.0       10113893.0
#
#           1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Country
# Zimbabwe        7049926.0        5202918.0    390757.0            41.7665
#
#           Growth Rate  World Population Percentage
# Country
# Zimbabwe       1.0204                          0.2

# %%
df2.filter(like = "United", axis = 0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country
# United Arab Emirates                9441129.0        9287289.0
# United Kingdom                     67508936.0       67059474.0
# United States                     338289857.0      335942003.0
# United States Virgin Islands          99465.0         100442.0
#
#                               2015 Population  2010 Population  \
# Country
# United Arab Emirates                8916899.0        8481771.0
# United Kingdom                     65224364.0       62760039.0
# ...

# %%
df2.loc["United States"]
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df2.iloc[3]
# Out:
# Rank                                 213
# CCA3                                 ASM
# Capital                        Pago Pago
# Continent                        Oceania
# 2022 Population                  44273.0
# 2020 Population                  46189.0
# 2015 Population                  51368.0
# 2010 Population                  54849.0
# 2000 Population                  58230.0
# 1990 Population                  47818.0
# 1980 Population                  32886.0
# 1970 Population                  27075.0
# Area (km²)                         199.0
# Density (per km²)               222.4774
# Growth Rate                       0.9831
# World Population Percentage          0.0
# Name: American Samoa, dtype: object

# %%
df[df["Rank"] <= 10].sort_values(by="Rank")
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
df[df["Rank"] <= 10].sort_values(by="Rank",ascending = False)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 131    10  MEX         Mexico       Mexico City  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 131     1.275041e+08     1.259983e+08     1.201499e+08     1.125324e+08
# 171     1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
# ...

# %%
df[df["Rank"] <= 10].sort_values(by=["Continent","Country"],ascending = [False,True])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 131    10  MEX         Mexico       Mexico City  North America
# 221     3  USA  United States  Washington, D.C.  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# 131     1.275041e+08     1.259983e+08     1.201499e+08     1.125324e+08
# ...

# %%
#Indexes in Pandas


import pandas as pd

df = pd.read_csv(r"C:\Users\sulta\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df = pd.read_csv(r"C:\Users\sulta\Downloads\world_population.csv", index_col = "Country")
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#                               Country      Continent  index  Rank CCA3  \
# 0                         Afghanistan           Asia      0    36  AFG
# 1                             Albania         Europe      1   138  ALB
# 2                             Algeria         Africa      2    34  DZA
# 3                      American Samoa        Oceania      3   213  ASM
# 4                             Andorra         Europe      4   203  AND
# 5                              Angola         Africa      5    42  AGO
# 6                            Anguilla  North America      6   224  AIA
# 7                 Antigua and Barbuda  North America      7   201  ATG
# 8                           Argentina  South America      8    33  ARG
# 9                             Armenia           Asia      9   140  ARM
# 10                              Aruba  North America     10   198  ABW
# 11                          Australia        Oceania     11    55  AUS
# ...

# %%
df.set_index("Country", inplace = True)
df
# Out:
#                                       Continent  index  Rank CCA3  \
# Country
# Afghanistan                                Asia      0    36  AFG
# Albania                                  Europe      1   138  ALB
# Algeria                                  Africa      2    34  DZA
# American Samoa                          Oceania      3   213  ASM
# Andorra                                  Europe      4   203  AND
# Angola                                   Africa      5    42  AGO
# Anguilla                          North America      6   224  AIA
# Antigua and Barbuda               North America      7   201  ATG
# Argentina                         South America      8    33  ARG
# Armenia                                    Asia      9   140  ARM
# Aruba                             North America     10   198  ABW
# Australia                               Oceania     11    55  AUS
# Austria                                  Europe     12    99  AUT
# ...

# %%
df.loc["Albania"]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df.iloc[1]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df.reset_index(inplace = True)
df
# Out:
#                               Country      Continent  index  Rank CCA3  \
# 0                         Afghanistan           Asia      0    36  AFG
# 1                             Albania         Europe      1   138  ALB
# 2                             Algeria         Africa      2    34  DZA
# 3                      American Samoa        Oceania      3   213  ASM
# 4                             Andorra         Europe      4   203  AND
# 5                              Angola         Africa      5    42  AGO
# 6                            Anguilla  North America      6   224  AIA
# 7                 Antigua and Barbuda  North America      7   201  ATG
# 8                           Argentina  South America      8    33  ARG
# 9                             Armenia           Asia      9   140  ARM
# 10                              Aruba  North America     10   198  ABW
# 11                          Australia        Oceania     11    55  AUS
# ...

# %%
df.set_index(["Country","Continent"],inplace = True)
df
# Out:
#                                                 index  Rank CCA3  \
# Country                          Continent
# Afghanistan                      Asia               0    36  AFG
# Albania                          Europe             1   138  ALB
# Algeria                          Africa             2    34  DZA
# American Samoa                   Oceania            3   213  ASM
# Andorra                          Europe             4   203  AND
# Angola                           Africa             5    42  AGO
# Anguilla                         North America      6   224  AIA
# Antigua and Barbuda              North America      7   201  ATG
# Argentina                        South America      8    33  ARG
# Armenia                          Asia               9   140  ARM
# Aruba                            North America     10   198  ABW
# Australia                        Oceania           11    55  AUS
# Austria                          Europe            12    99  AUT
# ...

# %%
df.sort_index(ascending = [False,True])
pd.set_option("display.max.rows",235)
df
# Out:
#                                                 index  Rank CCA3  \
# Country                          Continent
# Afghanistan                      Asia               0    36  AFG
# Albania                          Europe             1   138  ALB
# Algeria                          Africa             2    34  DZA
# American Samoa                   Oceania            3   213  ASM
# Andorra                          Europe             4   203  AND
# Angola                           Africa             5    42  AGO
# Anguilla                         North America      6   224  AIA
# Antigua and Barbuda              North America      7   201  ATG
# Argentina                        South America      8    33  ARG
# Armenia                          Asia               9   140  ARM
# Aruba                            North America     10   198  ABW
# Australia                        Oceania           11    55  AUS
# Austria                          Europe            12    99  AUT
# ...

# %%
df.loc["Angola","Africa"]
# Out:
# index                                   5
# Rank                                   42
# CCA3                                  AGO
# Capital                            Luanda
# 2022 Population                35588987.0
# 2020 Population                33428485.0
# 2015 Population                28127721.0
# 2010 Population                23364185.0
# 2000 Population                16394062.0
# 1990 Population                11828638.0
# 1980 Population                 8330047.0
# 1970 Population                 6029700.0
# Area (km²)                      1246700.0
# Density (per km²)                 28.5466
# Growth Rate                        1.0315
# World Population Percentage          0.45
# Name: (Angola, Africa), dtype: object

# %%
df.iloc[1]
# Out:
# index                                  1
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: (Albania, Europe), dtype: object

# %%
#Group by and Aggregating

import pandas as pd

df = pd.read_csv(r"C:\Users\sulta\Downloads\Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame = df.groupby("Base Flavor")
group_by_frame.mean()
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_728\1649719430.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_by_frame.mean()
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby("Base Flavor").mean()
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_728\1782637068.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Base Flavor").mean()
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby("Base Flavor").count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
df.groupby("Base Flavor").min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
df.groupby("Base Flavor").max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
df.groupby("Base Flavor").sum()
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_728\227357485.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Base Flavor").sum()
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate             25.2            21.7          47.1
# Vanilla               34.2            33.9          68.1

# %%
df.groupby("Base Flavor").agg({"Flavor Rating": ["mean","max","count","sum"], "Texture Rating": ["mean","max","count","sum"]})
# Out:
#             Flavor Rating                   Texture Rating
#                      mean   max count   sum           mean  max count   sum
# Base Flavor
# Chocolate             8.4   8.8     3  25.2       7.233333  7.6     3  21.7
# Vanilla               5.7  10.0     6  34.2       5.650000  8.0     6  33.9

# %%
df.groupby(["Base Flavor","Liked"]).mean()
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_728\3129628152.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Base Flavor","Liked"]).mean()
#                    Flavor Rating  Texture Rating  Total Rating
# Base Flavor Liked
# Chocolate   Yes              8.4        7.233333     15.700000
# Vanilla     No               3.6        4.466667      8.066667
#             Yes              7.8        6.833333     14.633333

# %%
df.groupby(["Base Flavor","Liked"]).agg({"Flavor Rating": ["mean","max","count","sum"]})
# Out:
#                   Flavor Rating
#                            mean   max count   sum
# Base Flavor Liked
# Chocolate   Yes             8.4   8.8     3  25.2
# Vanilla     No              3.6   4.7     3  10.8
#             Yes             7.8  10.0     3  23.4

# %%
df.groupby(["Base Flavor"]).describe()
# Out:
#             Flavor Rating                                             \
#                     count mean       std  min    25%  50%  75%   max
# Base Flavor
# Chocolate             3.0  8.4  0.346410  8.2  8.200  8.2  8.5   8.8
# Vanilla               6.0  5.7  2.710719  2.3  4.025  5.6  6.8  10.0
#
#             Texture Rating            ...             Total Rating         \
#                      count      mean  ...    75%  max        count   mean
# Base Flavor                           ...
# Chocolate              3.0  7.233333  ...  7.350  7.6          3.0  15.70
# Vanilla                6.0  5.650000  ...  6.375  8.0          6.0  11.35
#
#
#                   std   min     25%   50%     75%   max
# Base Flavor
# Chocolate    0.781025  15.2  15.250  15.3  15.950  16.6
# Vanilla      4.263684   5.7   9.025  11.1  13.175  18.0
#
# [2 rows x 24 columns]

# %%
#Merge, Join and Concatenate


import pandas as pd
df1 = pd.read_csv(r"C:\Users\sulta\Downloads\LOTR.csv")
df1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
df2 = pd.read_csv(r"C:\Users\sulta\Downloads\LOTR 2.csv")
df2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
df1.merge(df2)
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df1.merge(df2, how = "inner", on = "FellowshipID")
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y  Age
# 0          1001       Frodo     Hiding       Frodo   50
# 1          1002     Samwise  Gardening     Samwise   39

# %%
df1.merge(df2, how = "inner", on = ["FellowshipID","FirstName"])
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df1.merge(df2, how = "outer")
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
df1.merge(df2, how = "left")
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
df1.merge(df2, how = "right")
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %%
df1.merge(df2, how = "cross")
# Out:
#     FellowshipID_x FirstName_x     Skills  FellowshipID_y FirstName_y   Age
# 0             1001       Frodo     Hiding            1001       Frodo    50
# 1             1001       Frodo     Hiding            1002     Samwise    39
# 2             1001       Frodo     Hiding            1006     Legolas  2931
# 3             1001       Frodo     Hiding            1007      Elrond  6520
# 4             1001       Frodo     Hiding            1008    Barromir    51
# 5             1002     Samwise  Gardening            1001       Frodo    50
# 6             1002     Samwise  Gardening            1002     Samwise    39
# 7             1002     Samwise  Gardening            1006     Legolas  2931
# 8             1002     Samwise  Gardening            1007      Elrond  6520
# 9             1002     Samwise  Gardening            1008    Barromir    51
# 10            1003     Gandalf     Spells            1001       Frodo    50
# ...

# %%
df1.join(df2, on = "FellowshipID", how = "outer", lsuffix = "_Left", rsuffix = "_Right")
# Out:
#      FellowshipID  FellowshipID_Left FirstName_Left     Skills  \
# 0.0          1001             1001.0          Frodo     Hiding
# 1.0          1002             1002.0        Samwise  Gardening
# 2.0          1003             1003.0        Gandalf     Spells
# 3.0          1004             1004.0         Pippin  Fireworks
# NaN             0                NaN            NaN        NaN
# NaN             1                NaN            NaN        NaN
# NaN             2                NaN            NaN        NaN
# NaN             3                NaN            NaN        NaN
# NaN             4                NaN            NaN        NaN
#
#      FellowshipID_Right FirstName_Right     Age
# 0.0                 NaN             NaN     NaN
# 1.0                 NaN             NaN     NaN
# 2.0                 NaN             NaN     NaN
# 3.0                 NaN             NaN     NaN
# NaN              1001.0           Frodo    50.0
# ...

# %%
df4 = df1.set_index("FellowshipID").join(df2.set_index("FellowshipID"), lsuffix = "_Left", rsuffix = "_Right", how = "outer")
df4
# Out:
#              FirstName_Left     Skills FirstName_Right     Age
# FellowshipID
# 1001                  Frodo     Hiding           Frodo    50.0
# 1002                Samwise  Gardening         Samwise    39.0
# 1003                Gandalf     Spells             NaN     NaN
# 1004                 Pippin  Fireworks             NaN     NaN
# 1006                    NaN        NaN         Legolas  2931.0
# 1007                    NaN        NaN          Elrond  6520.0
# 1008                    NaN        NaN        Barromir    51.0

# %%
pd.concat([df1,df2])
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
pd.concat([df1,df2], join = "inner")
# Out:
#    FellowshipID FirstName
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1003   Gandalf
# 3          1004    Pippin
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1006   Legolas
# 3          1007    Elrond
# 4          1008  Barromir

# %%
pd.concat([df1,df2], join = "outer")
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
pd.concat([df1,df2], join = "outer", axis = 1)
# Out:
#    FellowshipID FirstName     Skills  FellowshipID FirstName   Age
# 0        1001.0     Frodo     Hiding          1001     Frodo    50
# 1        1002.0   Samwise  Gardening          1002   Samwise    39
# 2        1003.0   Gandalf     Spells          1006   Legolas  2931
# 3        1004.0    Pippin  Fireworks          1007    Elrond  6520
# 4           NaN       NaN        NaN          1008  Barromir    51

# %%
df1.append(df2)
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_10920\3062608662.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
#Pandas Visualizations


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\sulta\Downloads\Ice Cream Ratings.csv")
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df = df.set_index("Date")
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
print(plt.style.available)
plt.style.use("fivethirtyeight")
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot(kind = "line")
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = "line", subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind = "line", title = "Ice Cream Ratings", xlabel = "Daily Ratings", ylabel = "Scores")
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot(kind = "bar")
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = "bar", stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df["Flavor Rating"].plot(kind = "bar", stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter(x = "Texture Rating", y = "Overall Rating", s = 500, c = "Red")
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y = "Flavor Rating", figsize = (10,5))
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
#Data Cleaning in Pandas

import pandas as pd

df = pd.read_excel(r"C:\Users\sulta\Downloads\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#df["Last_Name"] = df["Last_Name"].str.lstrip("...")
#df["Last_Name"] = df["Last_Name"].str.lstrip("/")
#df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df["Phone_Number"] = df["Phone_Number"].str.replace("[^a-zA-Z0-9]","")
#df["Phone_Number"].apply(lambda x: x[0:3] + "-" + x[3:6] + "-" + x[6:10])
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + "-" + x[3:6] + "-" + x[6:10])
df["Phone_Number"] = df["Phone_Number"].str.replace("nan--","")
df["Phone_Number"] = df["Phone_Number"].str.replace("Na--","")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 1         1002       Abed       Nadir    123-643-97
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute    123-543-23
# 4         1005        Jon        Snow    876-678-34
# 5         1006        Ron     Swanson    304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes    876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker    123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper    123-543-23
# 13        1014     Leslie       Knope    876-678-34
# 14        1015       Toby  Flenderson    304-762-24
# 15        1016        Ron     Weasley    123-545-54
# 16        1017   Michael        Scott    123-643-97
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df[["Street_Address","State","Zip_Code"]] = df["Address"].str.split(",",2,expand = True)
df
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_7160\222423982.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[["Street_Address","State","Zip_Code"]] = df["Address"].str.split(",",2,expand = True)
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 1         1002       Abed       Nadir    123-643-97
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute    123-543-23
# 4         1005        Jon        Snow    876-678-34
# 5         1006        Ron     Swanson    304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes    876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker    123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes","Y")
df["Paying Customer"] = df["Paying Customer"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 1         1002       Abed       Nadir    123-643-97
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute    123-543-23
# 4         1005        Jon        Snow    876-678-34
# 5         1006        Ron     Swanson    304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes    876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker    123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper    123-543-23
# 13        1014     Leslie       Knope    876-678-34
# 14        1015       Toby  Flenderson    304-762-24
# 15        1016        Ron     Weasley    123-545-54
# 16        1017   Michael        Scott    123-643-97
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes","Y")
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 2         1003     Walter       White  706-695-0392
# 4         1005        Jon        Snow    876-678-34
# 7         1008   Sherlock      Holmes    876-678-34
# 9         1010      Peter      Parker    123-545-54
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper    123-543-23
# 13        1014     Leslie       Knope    876-678-34
# 14        1015       Toby  Flenderson    304-762-24
# 15        1016        Ron     Weasley    123-545-54
# 16        1017   Michael        Scott    123-643-97
# 17        1018      Clark        Kent  706-695-0392
# 19        1020     Anakin   Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N
# ...

# %%
df[["Address","Paying Customer","Street_Address"]] = df[["Address","Paying Customer","Street_Address"]].replace("N/a","")
#df.replace("NaN","")
df = df.fillna("")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 2         1003     Walter       White  706-695-0392
# 4         1005        Jon        Snow    876-678-34
# 7         1008   Sherlock      Holmes    876-678-34
# 9         1010      Peter      Parker    123-545-54
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper    123-543-23
# 13        1014     Leslie       Knope    876-678-34
# 14        1015       Toby  Flenderson    304-762-24
# 15        1016        Ron     Weasley    123-545-54
# 16        1017   Michael        Scott    123-643-97
# 17        1018      Clark        Kent  706-695-0392
# 19        1020     Anakin   Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N
# ...

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == "Y":
        df.drop(x, inplace = True)
        
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 2         1003     Walter       White  706-695-0392
# 4         1005        Jon        Snow    876-678-34
# 7         1008   Sherlock      Holmes    876-678-34
# 9         1010      Peter      Parker    123-545-54
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper    123-543-23
# 13        1014     Leslie       Knope    876-678-34
# 14        1015       Toby  Flenderson    304-762-24
# 15        1016        Ron     Weasley    123-545-54
# 16        1017   Michael        Scott    123-643-97
# 17        1018      Clark        Kent  706-695-0392
# 19        1020     Anakin   Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N
# ...

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == "":
        df.drop(x, inplace = True)
        
df

#another way to drop null values
# df = df.dropna(subset = "Phone_Number"),inplace = "True"
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 2         1003     Walter       White  706-695-0392
# 4         1005        Jon        Snow    876-678-34
# 7         1008   Sherlock      Holmes    876-678-34
# 9         1010      Peter      Parker    123-545-54
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper    123-543-23
# 13        1014     Leslie       Knope    876-678-34
# 14        1015       Toby  Flenderson    304-762-24
# 15        1016        Ron     Weasley    123-545-54
# 16        1017   Michael        Scott    123-643-97
# 17        1018      Clark        Kent  706-695-0392
# 19        1020     Anakin   Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N
# ...

# %%
df = df.reset_index(drop = True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins    123-545-54
# 1         1003     Walter       White  706-695-0392
# 2         1005        Jon        Snow    876-678-34
# 3         1008   Sherlock      Holmes    876-678-34
# 4         1010      Peter      Parker    123-545-54
# 5         1012      Harry      Potter  706-695-0392
# 6         1013        Don      Draper    123-543-23
# 7         1014     Leslie       Knope    876-678-34
# 8         1015       Toby  Flenderson    304-762-24
# 9         1016        Ron     Weasley    123-545-54
# 10        1017   Michael        Scott    123-643-97
# 11        1018      Clark        Kent  706-695-0392
# 12        1020     Anakin   Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 1               298 Drugs Driveway               N
# ...

# %%
#EDA(Exploratory Data Analysis) in Pandas

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\sulta\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
pd.set_option("display.float_format", lambda x: "%.2f" % x)
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by = "2022 Population", ascending = False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
df.sort_values(by = "World Population Percentage", ascending = False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
df.corr()
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_3160\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# ...

# %%
sns.heatmap(df.corr(), annot = True)
plt.rcParams["figure.figsize"] = (20,7)
plt.show()
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_3160\4048019380.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
df.groupby("Continent").mean()
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_3160\1051583130.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Continent").mean()
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Asia           77.56      96327387.31      94955134.37      89165003.64
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# ...

# %%
df.groupby("Continent").mean().sort_values(by = "2022 Population", ascending = False)
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_3160\3057556335.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Continent").mean().sort_values(by = "2022 Population", ascending = False)
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      96327387.31      94955134.37      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# ...

# %%
df[df["Continent"].str.contains("Oceania")]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
#df2 = df.groupby("Continent")[df.columns[5:13]].mean().sort_values(by = "2022 Population", ascending = False)

df2 = df.groupby("Continent")[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by = "2022 Population", ascending = False)
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# Europe             14817685.71      14712278.68      15027454.12
# North America      12151739.60      13568016.28      14259596.25
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df3 = df2.transpose()
df3
# Out:
# Continent              Asia  South America      Africa      Europe  \
# 1970 Population 43839877.83    13781939.71  6567175.27 13118479.82
# 1980 Population 40278333.33    17270643.29  8586031.98 14200004.52
# 1990 Population 48639995.33    21224743.93 11376964.52 14785203.94
# 2000 Population 80580835.11    25015888.69 14598365.95 14817685.71
# 2010 Population 89087770.00    26789395.54 18898197.31 14712278.68
# 2015 Population 89165003.64    29509599.71 21419703.57 15027454.12
# 2020 Population 94955134.37    30823574.50 23871435.26 14915843.92
# 2022 Population 96327387.31    31201186.29 25455879.68 15055371.82
#
# Continent        North America    Oceania
# 1970 Population     7885865.15  846968.26
# 1980 Population     9207334.03  996532.17
# 1990 Population    10531660.62 1162774.87
# 2000 Population    12151739.60 1357512.09
# 2010 Population    13568016.28 1613163.65
# 2015 Population    14259596.25 1756664.48
# 2020 Population    14855914.82 1910148.96
# ...

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize = (20,10))
# Out:
# <Axes: >

# %%
#df.select_dtypes(include = "number")
#df.select_dtypes(include = "object")
df.select_dtypes(include = "float")
# Out:
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# 2        44903225.00      43451666.00      39543154.00      35856344.00
# 3           44273.00         46189.00         51368.00         54849.00
# 4           79824.00         77700.00         71746.00         71519.00
# ..               ...              ...              ...              ...
# 229         11572.00         11655.00         12182.00         13142.00
# 230        575986.00        556048.00        491824.00        413296.00
# 231      33696614.00      32284046.00      28516545.00      24743946.00
# 232      20017675.00      18927715.00              NaN      13792086.00
# 233      16320537.00      15669666.00      14154937.00      12839771.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...
